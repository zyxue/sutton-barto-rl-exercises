# %% [markdown]
# Use lightgbm+shap as a reference to check the correctness of my own implementation.

# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
import shap
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
data = pd.DataFrame(
        [
            [206, 216, 388, 10],
            [206, 246, 314, 10],
            [206, 127, 243, 10],
            [206, 331, 287, 10],
            [206, 168, 346, 10],
            [194, 272, 368, 20],
            [6, 299, 298, 50],
            [6, 299, 339, 50],
            [6, 301, 301, 30],
            [6, 301, 116, 30],
        ],
        columns=['x1', 'x2', 'x3', "y"],
    )

X_train = data[['x1', 'x2', 'x3']]
y_train = data["y"]

X_test = pd.DataFrame([
    {
        'x1': 150,
        'x2': 75,
        'x3': 200
    }
])
