# %% [markdown]
# This notebook is mostly the same as LSTM-gates-investigation.ipynb, but with longer sequences and a large number of epochs.

# %%
import matplotlib.pyplot as plt
import matplotlib as mlp

mlp.style.use('classic')

# %matplotlib inline

# %%
import numpy as np

from keras.models import Model
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras.layers import Input, LSTM, LSTMCell, Dense, SimpleRNN
from keras.utils.vis_utils import plot_model
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def sigmoid(a):
    return 1 / (1 + np.exp(-a))

# %%
seq_len = 150
N = 10000
batch_size = 100

xs = np.zeros((N, seq_len))
ys = np.zeros(N)

# construct input data
positive_indexes = np.arange(N // 2)
negative_indexes = np.arange(N // 2, N)

xs[positive_indexes, 0] = 1
ys[positive_indexes] = 1

xs[negative_indexes, 0] = -1
ys[negative_indexes] = 0

noise = np.random.normal(loc=0, scale=0.1, size=(N, seq_len))

train_xs = (xs + noise).reshape(N, seq_len, 1)
train_ys = ys

# %%
for i in range(10):
    plt.plot(train_xs[i], color='red')
    plt.plot(train_xs[-i], color='blue')

# %%
# %%time
inputs = Input(shape=(None, 1), name='input')
rnn = LSTM(1, input_shape=(None, 1), name='rnn')
rnn_out = rnn(inputs)
dense = Dense(1, activation='sigmoid', name='output')
dense_out = dense(rnn_out)
model = Model(inputs, dense_out)
optm = Adam(lr=1e-3)
# optm = SGD(lr=1e-5, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.compile(optimizer=optm, loss='mse')

hist = model.fit(train_xs, train_ys,
                 batch_size=batch_size,
                 epochs=1000,
                 validation_split=0.2, 
                 verbose=1,
                 callbacks = [EarlyStopping(monitor='loss', min_delta=1e-5)]
                )
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/1000
# 8000/8000 [==============================] - 2s 287us/step - loss: 0.2462 - val_loss: 0.2877
# Epoch 2/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 0.2388 - val_loss: 0.3537
# Epoch 3/1000
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.2358 - val_loss: 0.3787
# Epoch 4/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2350 - val_loss: 0.3873
# Epoch 5/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2348 - val_loss: 0.3908
# Epoch 6/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.2346 - val_loss: 0.3902
# Epoch 7/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.2346 - val_loss: 0.3915
# Epoch 8/1000
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.2345 - val_loss: 0.3907
# Epoch 9/1000
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.2344 - val_loss: 0.3922
# Epoch 10/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 0.2344 - val_loss: 0.3911
# Epoch 11/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.2344 - val_loss: 0.3893
# Epoch 12/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2344 - val_loss: 0.3869
# Epoch 13/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2343 - val_loss: 0.3879
# Epoch 14/1000
# 8000/8000 [==============================] - 2s 227us/step - loss: 0.2342 - val_loss: 0.3889
# Epoch 15/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.2340 - val_loss: 0.3898
# Epoch 16/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2336 - val_loss: 0.3856
# Epoch 17/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.2309 - val_loss: 0.3771
# Epoch 18/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.1722 - val_loss: 0.2151
# Epoch 19/1000
# 8000/8000 [==============================] - 2s 226us/step - loss: 0.1127 - val_loss: 0.1626
# Epoch 20/1000
# 8000/8000 [==============================] - 2s 230us/step - loss: 0.0856 - val_loss: 0.1273
# Epoch 21/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.0671 - val_loss: 0.1016
# Epoch 22/1000
# 8000/8000 [==============================] - 2s 224us/step - loss: 0.0549 - val_loss: 0.0833
# Epoch 23/1000
# 8000/8000 [==============================] - 2s 226us/step - loss: 0.0469 - val_loss: 0.0696
# Epoch 24/1000
# 8000/8000 [==============================] - 2s 236us/step - loss: 0.0408 - val_loss: 0.0593
# Epoch 25/1000
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.0358 - val_loss: 0.0513
# Epoch 26/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0318 - val_loss: 0.0447
# Epoch 27/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0284 - val_loss: 0.0394
# Epoch 28/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0254 - val_loss: 0.0349
# Epoch 29/1000
# 8000/8000 [==============================] - 2s 234us/step - loss: 0.0229 - val_loss: 0.0312
# Epoch 30/1000
# 8000/8000 [==============================] - 2s 244us/step - loss: 0.0208 - val_loss: 0.0279
# Epoch 31/1000
# 8000/8000 [==============================] - 2s 241us/step - loss: 0.0189 - val_loss: 0.0251
# Epoch 32/1000
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.0172 - val_loss: 0.0227
# Epoch 33/1000
# 8000/8000 [==============================] - 2s 243us/step - loss: 0.0157 - val_loss: 0.0206
# Epoch 34/1000
# 8000/8000 [==============================] - 2s 239us/step - loss: 0.0144 - val_loss: 0.0186
# Epoch 35/1000
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.0132 - val_loss: 0.0170
# Epoch 36/1000
# 8000/8000 [==============================] - 2s 239us/step - loss: 0.0121 - val_loss: 0.0155
# Epoch 37/1000
# 8000/8000 [==============================] - 2s 236us/step - loss: 0.0111 - val_loss: 0.0142
# Epoch 38/1000
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.0103 - val_loss: 0.0130
# Epoch 39/1000
# 8000/8000 [==============================] - 2s 241us/step - loss: 0.0095 - val_loss: 0.0119
# Epoch 40/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0088 - val_loss: 0.0109
# Epoch 41/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0081 - val_loss: 0.0101
# Epoch 42/1000
# 8000/8000 [==============================] - 2s 236us/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 43/1000
# 8000/8000 [==============================] - 2s 231us/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 44/1000
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 45/1000
# 8000/8000 [==============================] - 2s 230us/step - loss: 0.0061 - val_loss: 0.0073
# Epoch 46/1000
# 8000/8000 [==============================] - 2s 225us/step - loss: 0.0056 - val_loss: 0.0067
# Epoch 47/1000
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.0053 - val_loss: 0.0062
# Epoch 48/1000
# 8000/8000 [==============================] - 2s 238us/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 49/1000
# 8000/8000 [==============================] - 2s 228us/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 50/1000
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 51/1000
# 8000/8000 [==============================] - 2s 230us/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 52/1000
# 8000/8000 [==============================] - 2s 225us/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 53/1000
# 8000/8000 [==============================] - 2s 235us/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 54/1000
# 8000/8000 [==============================] - 2s 228us/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 55/1000
# 8000/8000 [==============================] - 2s 243us/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 56/1000
# 8000/8000 [==============================] - 2s 235us/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 57/1000
# 8000/8000 [==============================] - 2s 237us/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 58/1000
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 59/1000
# 8000/8000 [==============================] - 2s 236us/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 60/1000
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 61/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 62/1000
# 8000/8000 [==============================] - 2s 219us/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 63/1000
# 8000/8000 [==============================] - 2s 219us/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 64/1000
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 65/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 66/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 67/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 68/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 69/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 70/1000
# 8000/8000 [==============================] - 2s 227us/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 71/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 72/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 73/1000
# 8000/8000 [==============================] - 2s 219us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 74/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 75/1000
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.0010 - val_loss: 9.4172e-04
# Epoch 76/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 9.7833e-04 - val_loss: 9.1053e-04
# Epoch 77/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 9.4630e-04 - val_loss: 8.9700e-04
# Epoch 78/1000
# 8000/8000 [==============================] - 2s 211us/step - loss: 9.1731e-04 - val_loss: 8.8201e-04
# Epoch 79/1000
# 8000/8000 [==============================] - 2s 212us/step - loss: 8.8966e-04 - val_loss: 8.6643e-04
# Epoch 80/1000
# 8000/8000 [==============================] - 2s 219us/step - loss: 8.6317e-04 - val_loss: 8.5006e-04
# Epoch 81/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 8.3775e-04 - val_loss: 8.3300e-04
# Epoch 82/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 8.1332e-04 - val_loss: 8.1486e-04
# Epoch 83/1000
# 8000/8000 [==============================] - 2s 211us/step - loss: 7.8978e-04 - val_loss: 7.9645e-04
# Epoch 84/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 7.6709e-04 - val_loss: 7.7763e-04
# Epoch 85/1000
# 8000/8000 [==============================] - 2s 212us/step - loss: 7.4519e-04 - val_loss: 7.5863e-04
# Epoch 86/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 7.2403e-04 - val_loss: 7.3906e-04
# Epoch 87/1000
# 8000/8000 [==============================] - 2s 222us/step - loss: 7.0358e-04 - val_loss: 7.1943e-04
# Epoch 88/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 6.8379e-04 - val_loss: 7.0023e-04
# Epoch 89/1000
# 8000/8000 [==============================] - 2s 217us/step - loss: 6.6466e-04 - val_loss: 6.8080e-04
# Epoch 90/1000
# 8000/8000 [==============================] - 2s 212us/step - loss: 6.4614e-04 - val_loss: 6.6144e-04
# Epoch 91/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 6.2820e-04 - val_loss: 6.4227e-04
# Epoch 92/1000
# 8000/8000 [==============================] - 2s 235us/step - loss: 6.1084e-04 - val_loss: 6.2301e-04
# Epoch 93/1000
# 8000/8000 [==============================] - 2s 221us/step - loss: 4.7518e-04 - val_loss: 6.0391e-04
# Epoch 94/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 4.5873e-04 - val_loss: 5.8486e-04
# Epoch 95/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 4.4280e-04 - val_loss: 5.6603e-04
# Epoch 96/1000
# 8000/8000 [==============================] - 2s 213us/step - loss: 4.2738e-04 - val_loss: 5.4801e-04
# Epoch 97/1000
# 8000/8000 [==============================] - 2s 213us/step - loss: 4.1245e-04 - val_loss: 5.3021e-04
# Epoch 98/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 3.9801e-04 - val_loss: 5.1240e-04
# Epoch 99/1000
# 8000/8000 [==============================] - 2s 217us/step - loss: 3.8403e-04 - val_loss: 4.9562e-04
# Epoch 100/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 3.7051e-04 - val_loss: 4.7885e-04
# Epoch 101/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 3.5744e-04 - val_loss: 4.6261e-04
# Epoch 102/1000
# 8000/8000 [==============================] - 2s 223us/step - loss: 3.4479e-04 - val_loss: 4.4705e-04
# Epoch 103/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 3.3256e-04 - val_loss: 4.3173e-04
# Epoch 104/1000
# 8000/8000 [==============================] - 2s 214us/step - loss: 3.2074e-04 - val_loss: 4.1688e-04
# Epoch 105/1000
# 8000/8000 [==============================] - 2s 220us/step - loss: 3.0931e-04 - val_loss: 4.0244e-04
# Epoch 106/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 2.9827e-04 - val_loss: 3.8836e-04
# Epoch 107/1000
# 8000/8000 [==============================] - 2s 215us/step - loss: 2.8760e-04 - val_loss: 3.7473e-04
# Epoch 108/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 2.7729e-04 - val_loss: 3.6172e-04
# Epoch 109/1000
# 8000/8000 [==============================] - 2s 218us/step - loss: 2.6734e-04 - val_loss: 3.4868e-04
# CPU times: user 7min 44s, sys: 3min 9s, total: 10min 53s
# Wall time: 3min 17s

# %%
fig, axes = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(8, 3.5))
axes = axes.ravel()

for k, keys in enumerate([['loss', 'val_loss'],
#                           ['acc', 'val_acc']
                         ]):
    ax = axes[k]
    
    for key in keys:
        ax.plot(hist.history[key], 'o-', label=key)
    ax.grid()
    ax.legend(loc='best')
plt.tight_layout()

# %%
# the positive and negative only vary by a small difference considering output from sigmoid
plt.plot(model.predict(train_xs))

# %% [markdown]
# ref: http://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# Since the input at each time step is only 1 dimension, so I used $w$ (scalar) instead of $W$ (matrix).

# %% [markdown]
# <img src="./lstm.png" width=600/>

# %% [markdown]
# Calculate gates:
#
# \begin{align*}
# f_t &= \sigma(w_f[h_{t-1}, x_t] + b_f) \\
# i_t &= \sigma(w_i[h_{t-1}, x_t] + b_i) \\
# \tilde{C}_t &= \tanh(w_C[h_{t-1}, x_t] + b_C) \\
# o_t &= \sigma(w_o[h_{t-1}, x_t] + b_o)
# \end{align*}
#
# Update $C_t$ and $h_t$,
# \begin{align*}
# C_t &= f_t * C_{t-1} + i_t * \tilde{C}_t \\
# h_t &= o_t * \tanh(C_t)
# \end{align*}

# %%
rnn.get_weights()
# Out:
# [array([[ 7.4881846e-01, -3.9799666e-01, -9.0379053e-01, -3.7696099e-04]],
#        dtype=float32),
#  array([[ 0.18907575, -0.2666904 ,  1.048734  ,  0.00183203]],
#        dtype=float32),
#  array([0.969188  , 2.068001  , 0.18305524, 2.5023916 ], dtype=float32)]

# %%
# ref: https://github.com/keras-team/keras/blob/d035967a5d2795734c89a0a3c002f7eb5c34eff1/keras/layers/recurrent.py#L1865
kernel = np.array(rnn.get_weights()[:2])[:,0,:]
kernel
# Out:
# array([[ 7.4881846e-01, -3.9799666e-01, -9.0379053e-01, -3.7696099e-04],
#        [ 1.8907575e-01, -2.6669040e-01,  1.0487339e+00,  1.8320297e-03]],
#       dtype=float32)

# %%
w_i, w_f, w_c, w_o = kernel.T
b_i, b_f, b_c, b_o = rnn.get_weights()[-1]

# %%
print(w_i, b_i)
print(w_f, b_f)
print(w_c, b_c)
print(w_o, b_o)
# Out:
# [0.74881846 0.18907575] 0.969188
# [-0.39799666 -0.2666904 ] 2.068001
# [-0.90379053  1.048734  ] 0.18305524
# [-0.00037696  0.00183203] 2.5023916

# %%
d_w0 = dense.get_weights()[0][0]
d_b0 = dense.get_weights()[1]
print(d_w0, d_b0)
# Out:
# [-4.0906587] [0.1274348]

# %%
for k, single_x in enumerate([train_xs[0], train_xs[1], train_xs[-2], train_xs[-1]]):
    h_prev = 0
    C_prev = 0

    hist = []
    for t in range(single_x.shape[0]):
    #     cat_x = [h_prev, single_x[t][0]]
        cat_x = [single_x[t][0], h_prev]
        f_t = sigmoid(np.dot(w_f, cat_x) + b_f)
        i_t = sigmoid(np.dot(w_i, cat_x) + b_i)
        B_t = np.tanh(np.dot(w_c, cat_x) + b_c) # use B to mean \tilde{C}
        o_t = sigmoid(np.dot(w_o, cat_x) + b_o)

        C_t = f_t * C_prev + i_t * B_t
        h_t = o_t * np.tanh(C_t)

        hist.append([f_t, i_t, B_t, o_t, C_t, h_t])

        h_prev = h_t
        C_prev = C_t
    den_in = hist[-1][-1]
    out = sigmoid(den_in * d_w0 + d_b0)
    print(out, model.predict(np.array([single_x])))
# Out:
# [0.9803003] [[0.985487]]
# [0.98029995] [[0.9854871]]
# [0.02526205] [[0.01867367]]
# [0.025259] [[0.01867065]]

# %% [markdown]
# The mannual process and model prediction are highly correlated, but still not the same...., in constrast to simpler SimpleRNN process in another notebook.

# %% [markdown]
# # Single x debugging and time step visualization

# %%
single_x = train_xs[5]
# single_x

# %%
h_prev = 0
C_prev = 0

hist = []
for t in range(single_x.shape[0]):
#     cat_x = [h_prev, single_x[t][0]]
    cat_x = [single_x[t][0], h_prev]
    f_t = sigmoid(np.dot(w_f, cat_x) + b_f)
    i_t = sigmoid(np.dot(w_i, cat_x) + b_i)
    B_t = np.tanh(np.dot(w_c, cat_x) + b_c) # use B to mean \tilde{C}
    o_t = sigmoid(np.dot(w_o, cat_x) + b_o)

    C_t = f_t * C_prev + i_t * B_t
    h_t = o_t * np.tanh(C_t)

    hist.append([f_t, i_t, B_t, o_t, C_t, h_t])

    h_prev = h_t
    C_prev = C_t

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 6), 
#                          sharex=True, sharey=True
                        )
axes = axes.ravel()

for k, i in enumerate([
    'forget_gate', 'input_gate', 'input_candidate', 'output_gate', 
    'cell_state', 'hidden_state'
]):
    ax = axes[k]
    ax.plot(np.array(hist)[:,k], 'o-', label=i)
    ax.legend(loc='best')
    ax.grid()
    
    if k in [0, 1, 3]:
        ax.set_ylim(0, 1)
    if k == 2:
        ax.set_ylim(-1, 1)

plt.tight_layout()

# %% [markdown]
# So seems that `input_candidate` are completely ignored

# %%
dense.get_weights()
# Out:
# [array([[-4.0906587]], dtype=float32), array([0.1274348], dtype=float32)]

# %%
# den_in = hist[-1][-1] # dense input
den_in = hist[-1][-1]

# %%
den_in
# Out:
# -0.923949012815889

# %%
d_w0 = dense.get_weights()[0][0]
d_b0 = dense.get_weights()[1]
print(d_w0, d_b0)
# Out:
# [-4.0906587] [0.1274348]

# %%
sigmoid(den_in * d_w0 + d_b0)
# Out:
# array([0.98029524], dtype=float32)

# %%
model.predict(np.array([single_x]))
# Out:
# array([[0.985487]], dtype=float32)

# %% [markdown]
# Followed equations from [colah's blog](http://colah.github.io/posts/2015-08-Understanding-LSTMs/), but there is always inconsistency....
