# %% [markdown]
# Initially, trying to come up with a loss function of two variables, but then realized that it would be difficult to figure out the underlying distribution and data that leads to loss function.
#
# So, the notebook is committed just for visualization purpose.

# %%
from eda_imports import *
# Out:
# <style>
#    div#notebook-container    { width: 100%; }
#    div#menubar-container     { width: 100%; }
#    div#maintoolbar-container { width: 100%; }
# </style>

# %%
from gaussian3D import mixed_gaussian

# %%
# %matplotlib notebook

# %% [markdown]
# # Make up an artificial loss surface

# %%
xs, ys = np.mgrid[-3:3:.1, -3:3:.1]

pos = np.empty(xs.shape + (2,))

pos[:, :, 0] = xs
pos[:, :, 1] = ys

zs = mixed_gaussian(pos)
# plt.contourf(xs, ys, zs)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.gca(projection='3d')
ax.plot_surface(xs, ys, zs, rstride=1, cstride=1, cmap=mpl.cm.coolwarm,
                linewidth=0, antialiased=False)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
# Out:
# <img src="data:image/png;base64,..." width="576">
# Text(0.5,0,'y')
